# %%
import pandas as pd
df = pd.read_csv("Tweets.csv")
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
colour=sns.color_palette()

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
# Product Scores
fig = px.histogram(df, x="airline_sentiment_confidence")
fig.update_traces(marker_color="red", marker_line_color='red', marker_line_width=1.5)
fig.update_layout(title_text='Product Score')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from wordcloud import WordCloud, STOPWORDS
stopwords=set(STOPWORDS)

#stopp= stopwords.update(["br","href"])
#stopp= set(stopwords.words("br","href"))''
stopwords = nltk.corpus.stopwords.words('english')

newStopWords = ['http','united','AmericanAir','SouthwestAir','JetBlue','flight','USAirways','airline']
stopwords.extend(newStopWords)
textt= " ".join(review for review in df.text)
wordcloud = WordCloud(stopwords=stopwords).generate(textt)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud1.png')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df['sentiment_score'] = df['airline_sentiment'].apply(lambda airline_sentiment : +1 if airline_sentiment=="positive" else -1 if
                                                     airline_sentiment == "negative" else 0)
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
positive = df[df['sentiment_score']==1]
negative = df[df['sentiment_score']==-1]
neutral = df[df['sentiment_score']==0]

# %%
positive
# Out:
#                  tweet_id airline_sentiment  airline_sentiment_confidence  \
# 1      570301130888122368          positive                        0.3486
# 6      570300616901320704          positive                        0.6745
# 8      570299953286942721          positive                        0.6559
# 9      570295459631263746          positive                        1.0000
# 11     570289724453216256          positive                        1.0000
# ...                   ...               ...                           ...
# 14623  569590013278756865          positive                        0.6274
# 14625  569589643487928321          positive                        1.0000
# 14628  569588651925098496          positive                        1.0000
# 14630  569588473050611712          positive                        1.0000
# 14635  569587686496825344          positive                        0.3487
#
#       negativereason  negativereason_confidence         airline  \
# ...

# %%
positive.negativereason
# Out:
# 1        NaN
# 6        NaN
# 8        NaN
# 9        NaN
# 11       NaN
#         ...
# 14623    NaN
# 14625    NaN
# 14628    NaN
# 14630    NaN
# 14635    NaN
# Name: negativereason, Length: 2363, dtype: object

# %%
negative.negativereason
# Out:
# 3                    Bad Flight
# 4                    Can't Tell
# 5                    Can't Tell
# 15                  Late Flight
# 17                   Bad Flight
#                   ...
# 14631                Bad Flight
# 14633          Cancelled Flight
# 14634               Late Flight
# 14636    Customer Service Issue
# 14638    Customer Service Issue
# Name: negativereason, Length: 9178, dtype: object

# %%
stopwords = set(STOPWORDS)
stopwords.update(['http','united','AmericanAir','SouthwestAir','JetBlue','flight','USAirways','airline'])
## good and great removed because they were included in negative sentiment
neg = " ".join(review for review in negative.negativereason)
wordcloud2 = WordCloud(stopwords=stopwords).generate(neg)
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
neg = " ".join(review for review in negative.negativereason)
wordcloud3 = WordCloud(stopwords=stopwords).generate(neg)
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis("off")
plt.savefig('wordcloud33.png')
plt.show()

# %%
fig = px.histogram(df, x="airline_sentiment")
# fig.update_traces(marker_color="indianred",
#                   marker_line_width=1.5)
# fig.update_layout(title_text='Product Sentiment')
fig.show()
# Out:
# <div>                            <div id="d52c9b5f-343c-4519-a567-a87451589277" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d52c9b5f-343c-4519-a567-a87451589277")) {                    Plotly.newPlot(                        "d52c9b5f-343c-4519-a567-a87451589277",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"airline_sentiment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["neutral","positive","neutral","negative","negative","negative","positive","neutral","positive","positive","neutral","positive","positive","positive","positive","negative","positive","
# ...

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
def remove_punctuation(text):
    final = "".join(i for i in text if i not in ("?", ".", ";", ":",  "!",'"','@'))
    return final

df['text']= df['text'].apply(remove_punctuation)
# df=df.dropna(subset=['Summary'])
# df['Summary']= df['Summary'].apply(remove_punctuation)

# %%
dfNew = df[['text','airline_sentiment']]
dfNew.head()
# Out:
#                                                 text airline_sentiment
# 0                   VirginAmerica What dhepburn said           neutral
# 1  VirginAmerica plus you've added commercials to...          positive
# 2  VirginAmerica I didn't today Must mean I need ...           neutral
# 3  VirginAmerica it's really aggressive to blast ...          negative
# 4  VirginAmerica and it's a really big bad thing ...          negative

# %%
# random split train and test data
import numpy as np
index = df.index
df['random_number'] = np.random.randn(len(index))
train = df[df['random_number'] <= 0.8]
test = df[df['random_number'] > 0.8]

# %%
# count vectorizer:
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(token_pattern=r'\b\w+\b')
train_matrix = vectorizer.fit_transform(train['text'])
test_matrix = vectorizer.transform(test['text'])

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
X_train = train_matrix
X_test = test_matrix
y_train = train['airline_sentiment']
y_test = test['airline_sentiment']

# %%
lr.fit(X_train,y_train)
predictions = lr.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
# find accuracy, precision, recall:
from sklearn.metrics import confusion_matrix,classification_report
new = np.asarray(y_test)
confusion_matrix(predictions,y_test)
# Out:
# array([[1808,  186,   92],
#        [ 136,  427,   79],
#        [  64,   49,  346]])

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.90      0.87      0.88      2086
#      neutral       0.65      0.67      0.65       642
#     positive       0.67      0.75      0.71       459
#
#     accuracy                           0.81      3187
#    macro avg       0.74      0.76      0.75      3187
# weighted avg       0.82      0.81      0.81      3187
